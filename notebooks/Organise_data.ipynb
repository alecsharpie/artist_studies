# %%
os.mkdir('../raw_data/batch 2/tmp/te')
os.rename('../raw_data/batch 2/tmp/test.png', '../raw_data/batch 2/tmp/te/st.png')

# %%
import os
for file_name in os.listdir('../raw_data/batch 2'):
    if file_name[-3:] == 'png':
        artist_name = file_name[:-8]
        image_name = file_name[-7:]
        print(artist_name, image_name)
        if artist_name not in os.listdir(f'../raw_data/batch 2/'): 
            os.mkdir(f'../raw_data/batch 2/{artist_name}')
        os.rename(f'../raw_data/batch 2/{artist_name}_{image_name}', f'../raw_data/batch 2/{artist_name}/{image_name}')
# Out:
# Caldwell_Clyde 1_1.png
# Ciurlionis_Mikalojus_Konstantinas 0_2.png
# Chagall_Marcel 0_0.png
# Dohanos_Stevan 0_2.png
# Elliott_Harold 1_0.png
# Bussière_Gaston 0_2.png
# Deharme_Lise 1_2.png
# Deharme_Lise 1_0.png
# Bussière_Gaston 0_0.png
# Elliott_Harold 1_2.png
# Ciurlionis_Mikalojus_Konstantinas 0_0.png
# Dohanos_Stevan 0_0.png
# Chagall_Marcel 0_2.png
# Blair_Mary 0_0.png
# Caniglia_Jeremy 0_1.png
# Castiglione_Giovanni_Benedetto 0_0.png
# Castiglione_Giovanni_Benedetto 0_1.png
# Caniglia_Jeremy 0_0.png
# Blair_Mary 0_1.png
# Caldwell_Clyde 1_2.png
# Dohanos_Stevan 0_1.png
# Ciurlionis_Mikalojus_Konstantinas 0_1.png
# Bussière_Gaston 0_1.png
# Deharme_Lise 1_1.png
# Bridgwater_Emmy 1_1.png
# Frazetta_Frank 0_1.png
# Doré_Gustave 0_0.png
# Burne-Jones_Edward 1_0.png
# Blasingame_Marguerite 0_0.png
# Fernández_Agustín 0_1.png
# Canty_Thomas 0_1.png
# De_Morgan_Evelyn 0_2.png
# Brosnan_Pierce 0_2.png
# Ejsing_Jesper 0_2.png
# Canty_Thomas 0_0.png
# ...
