# %%
os.mkdir('../raw_data/batch 2/tmp/te')
os.rename('../raw_data/batch 2/tmp/test.png', '../raw_data/batch 2/tmp/te/st.png')

# %%
import os
for file_name in os.listdir('../raw_data/batch 2 2'):
    if file_name[-3:] == 'png':
        artist_name = file_name[:-8]
        image_name = file_name[-7:]
        print(artist_name, image_name)
        if artist_name not in os.listdir(f'../raw_data/batch 2 2/'): 
            os.mkdir(f'../raw_data/batch 2 2/{artist_name}')
        os.rename(f'../raw_data/batch 2 2/{artist_name}_{image_name}', f'../raw_data/batch 2 2/{artist_name}/{image_name}')
# Out:
# Zirnite_Nele 0_1.png
# Minguez_Victor_Adame 0_2.png
# Summers_Scott_Samuel 0_1.png
# Jedruszek_Tomasz 0_2.png
# Balbusso_Anna_and_Elena 0_0.png
# Xuan_Qian 0_1.png
# Roerich_Nicholas 1_2.png
# Xuan_Qian 0_0.png
# Balbusso_Anna_and_Elena 0_1.png
# Summers_Scott_Samuel 0_0.png
# Zirnite_Nele 0_2.png
# Repin_Ilya 1_2.png
# Edlin_Tyler 1_2.png
# Luks_George 1_1.png
# Ito_Junji 1_1.png
# Aagaard_Zacharias_Martin 0_2.png
# RHADS 1_1.png
# Trouille_Clovis 1_2.png
# Ito_Junji 1_0.png
# Luks_George 1_0.png
# Edlin_Tyler 1_3.png
# Repin_Ilya 1_1.png
# Edlin_Tyler 1_1.png
# Ito_Junji 1_2.png
# Luks_George 1_2.png
# Trouille_Clovis 1_0.png
# RHADS 1_2.png
# Aagaard_Zacharias_Martin 0_1.png
# RHADS 1_3.png
# Aagaard_Zacharias_Martin 0_0.png
# Trouille_Clovis 1_1.png
# Repin_Ilya 1_0.png
# Xuan_Qian 1_1.png
# RHADS 0_4.png
# Jedruszek_Tomasz 1_2.png
# Summers_Scott_Samuel 1_1.png
# Balbusso_Anna_and_Elena 1_0.png
# Minguez_Victor_Adame 1_2.png
# Zirnite_Nele 1_2.png
# ...
